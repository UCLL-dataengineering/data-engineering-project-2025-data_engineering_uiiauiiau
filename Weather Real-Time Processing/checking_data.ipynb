# %%
# Import necessary libraries
import pandas as pd
from reader import Reader

# Load the data using the Reader class
reader = Reader('input/GlobalWeatherRepository.csv')
data = reader.load_data()

# Display the first 5 rows of the dataset
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66263 entries, 0 to 66262
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       66263 non-null  object
#  1   location_name                 66263 non-null  object
#  2   latitude                      66263 non-null  float64
#  3   longitude                     66263 non-null  float64
#  4   timezone                      66263 non-null  object
#  5   last_updated_epoch            66263 non-null  int64
#  6   last_updated                  66263 non-null  object
#  7   temperature_celsius           66263 non-null  float64
#  8   temperature_fahrenheit        66263 non-null  float64
#  9   condition_text                66263 non-null  object
#  10  wind_mph                      66263 non-null  float64
#  11  wind_kph                      66263 non-null  float64
#  12  wind_degree                   66263 non-null  int64
#  13  wind_direction                66263 non-null  object
#  14  pressure_mb                   66263 non-null  float64
#  15  pressure_in                   66263 non-null  float64
#  16  precip_mm                     66263 non-null  float64
#  17  precip_in                     66263 non-null  float64
#  18  humidity                      66263 non-null  int64
#  19  cloud                         66263 non-null  int64
#  20  feels_like_celsius            66263 non-null  float64
#  21  feels_like_fahrenheit         66263 non-null  float64
#  22  visibility_km                 66263 non-null  float64
#  23  visibility_miles              66263 non-null  float64
#  24  uv_index                      66263 non-null  float64
#  25  gust_mph                      66263 non-null  float64
#  26  gust_kph                      66263 non-null  float64
#  27  air_quality_Carbon_Monoxide   66263 non-null  float64
#  28  air_quality_Ozone             66263 non-null  float64
#  29  air_quality_Nitrogen_dioxide  66263 non-null  float64
#  30  air_quality_Sulphur_dioxide   66263 non-null  float64
#  31  air_quality_PM2.5             66263 non-null  float64
#  32  air_quality_PM10              66263 non-null  float64
#  33  air_quality_us-epa-index      66263 non-null  int64
#  34  air_quality_gb-defra-index    66263 non-null  int64
#  35  sunrise                       66263 non-null  object
#  36  sunset                        66263 non-null  object
#  37  moonrise                      66263 non-null  object
#  38  moonset                       66263 non-null  object
#  39  moon_phase                    66263 non-null  object
#  40  moon_illumination             66263 non-null  int64
# dtypes: float64(23), int64(7), object(11)
# memory usage: 20.7+ MB
# None

# %%
# Check for null values in each column
null_counts = data.isnull().sum()

# Print the null counts for each column
print("Null values in each column:")
print(null_counts)
# Out:
# Null values in each column:
# country                         0
# location_name                   0
# latitude                        0
# longitude                       0
# timezone                        0
# last_updated_epoch              0
# last_updated                    0
# temperature_celsius             0
# temperature_fahrenheit          0
# condition_text                  0
# wind_mph                        0
# wind_kph                        0
# wind_degree                     0
# wind_direction                  0
# pressure_mb                     0
# pressure_in                     0
# precip_mm                       0
# precip_in                       0
# humidity                        0
# cloud                           0
# feels_like_celsius              0
# feels_like_fahrenheit           0
# visibility_km                   0
# visibility_miles                0
# uv_index                        0
# gust_mph                        0
# gust_kph                        0
# air_quality_Carbon_Monoxide     0
# air_quality_Ozone               0
# air_quality_Nitrogen_dioxide    0
# air_quality_Sulphur_dioxide     0
# air_quality_PM2.5               0
# air_quality_PM10                0
# air_quality_us-epa-index        0
# air_quality_gb-defra-index      0
# sunrise                         0
# sunset                          0
# moonrise                        0
# moonset                         0
# moon_phase                      0
# moon_illumination               0
# dtype: int64

# %%
#investigate the data 
print(data.dtypes)
# Out:
# country                          object
# location_name                    object
# latitude                        float64
# longitude                       float64
# timezone                         object
# last_updated_epoch                int64
# last_updated                     object
# temperature_celsius             float64
# temperature_fahrenheit          float64
# condition_text                   object
# wind_mph                        float64
# wind_kph                        float64
# wind_degree                       int64
# wind_direction                   object
# pressure_mb                     float64
# pressure_in                     float64
# precip_mm                       float64
# precip_in                       float64
# humidity                          int64
# cloud                             int64
# feels_like_celsius              float64
# feels_like_fahrenheit           float64
# visibility_km                   float64
# visibility_miles                float64
# uv_index                        float64
# gust_mph                        float64
# gust_kph                        float64
# air_quality_Carbon_Monoxide     float64
# air_quality_Ozone               float64
# air_quality_Nitrogen_dioxide    float64
# air_quality_Sulphur_dioxide     float64
# air_quality_PM2.5               float64
# air_quality_PM10                float64
# air_quality_us-epa-index          int64
# air_quality_gb-defra-index        int64
# sunrise                          object
# sunset                           object
# moonrise                         object
# moonset                          object
# moon_phase                       object
# moon_illumination                 int64
# dtype: object
